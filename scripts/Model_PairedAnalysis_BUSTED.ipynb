# %%
# =============================================================================
# Imports
# =============================================================================
import os
import sys
import json
import csv

# %%
# =============================================================================
# Declares
# =============================================================================
# Empirical 13-datasets

# BUSTED
BUSTEDS_DIR = "/Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS"
BUSTEDS_MH_DIR = "/Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH"
BUSTEDS_OUTPUT_CSV = "PROCESSED_PairedAnalysis_13datasets_BUSTEDS-MH_vs_BUSTEDS.csv"

# aBSREL
aBSREL_DIR = "/Users/user/Documents/BS-MH/analysis/13-datasets/aBSREL"
aBSREL_MH_DIR = "/Users/user/Documents/BS-MH/analysis/13-datasets/aBSREL-MH"
aBSREL_OUTPUT_CSV = "PROCESSED_PairedAnalysis_13datasets_aBSREL-MH_vs_aBSREL.csv"

# %%
def read_json_BUSTEDS(filename):
    print("# Reading:", filename)
    if os.stat(filename).st_size == 0: return 9999991 
    with open(filename, "r") as fh:
        json_data = json.load(fh)
    fh.close()
    p_value = json_data["test results"]["p-value"]
    BASE_Unconstrained_cAIC = json_data["fits"]["Unconstrained model"]["AIC-c"]
    BASE_Unconstrained_log_L = json_data["fits"]["Unconstrained model"]["Log Likelihood"]
    print("\tBaseline model (BUSTEDS) p-value =", p_value)
    print("\tBaseline model (BUSTEDS) Unconstrained cAIC =", BASE_Unconstrained_cAIC)
    print("\tBaseline model (BUSTEDS) Unconstrained logL =", BASE_Unconstrained_log_L)
    return p_value, BASE_Unconstrained_cAIC, BASE_Unconstrained_log_L
#end method

def read_json_BUSTEDS_MH(filename_MH):
    print("# Reading:", filename_MH)
    if os.stat(filename_MH).st_size == 0: return 9999990
    with open(filename_MH, "r") as fh:
        json_data = json.load(fh)
    fh.close()
    # Part 1 - MG94 with double and triple instantaneous substitutions"
    p_value = json_data["test results"]["p-value"]
    MH_cAIC = json_data["fits"]["MG94 with double and triple instantaneous substitutions"]["AIC-c"]
    MH_log_L = json_data["fits"]["MG94 with double and triple instantaneous substitutions"]["Log Likelihood"]
    MH_dNdS = json_data["fits"]["MG94 with double and triple instantaneous substitutions"]["Rate Distributions"]["non-synonymous/synonymous rate ratio for *test*"]
    MH_DH_rate = json_data["fits"]["MG94 with double and triple instantaneous substitutions"]["Rate Distributions"]["rate at which 2 nucleotides are changed instantly within a single codon"]
    MH_TH_rate = json_data["fits"]["MG94 with double and triple instantaneous substitutions"]["Rate Distributions"]["rate at which 3 nucleotides are changed instantly within a single codon"]
    MH_TH_SI_rate = json_data["fits"]["MG94 with double and triple instantaneous substitutions"]["Rate Distributions"]["rate at which 3 nucleotides are changed instantly within a single codon between synonymous codon islands"]
    # Part 2 - "Unconstrained model"
    MH_Unconstrained_cAIC = json_data["fits"]["Unconstrained model"]["AIC-c"]
    MH_Unconstrained_log_L = json_data["fits"]["Unconstrained model"]["Log Likelihood"]
    #UN_SRV_0 = json_data["fits"]["Unconstrained model"]["Rate Distributions"]["Synonymous site-to-site rates"]
    #UN_SRV_1 = json_data["fits"]["Unconstrained model"]["Rate Distributions"]["Synonymous site-to-site rates"]
    #UN_SRV_2 = json_data["fits"]["Unconstrained model"]["Rate Distributions"]["Synonymous site-to-site rates"]
    MH_Unconstrained_DH_rate = json_data["fits"]["Unconstrained model"]["rate at which 2 nucleotides are changed instantly within a single codon"]
    MH_Unconstrained_TH_rate = json_data["fits"]["Unconstrained model"]["rate at which 3 nucleotides are changed instantly within a single codon"]
    MH_Unconstrained_TH_SI_rate = json_data["fits"]["Unconstrained model"]["rate at which 3 nucleotides are changed instantly within a single codon between synonymous codon islands"]
    #Report on what we found.
    print("\tNovel model (BUSTEDS-MH) p-value =", p_value)
    print("\tNovel model (BUSTEDS-MH) cAIC =", MH_Unconstrained_cAIC)
    print("\tNovel model (BUSTEDS-MH) logL =", MH_Unconstrained_log_L)
    return p_value, MH_cAIC, MH_log_L, MH_dNdS, MH_DH_rate, MH_TH_rate, MH_TH_SI_rate, MH_Unconstrained_cAIC, MH_Unconstrained_log_L, MH_Unconstrained_DH_rate, \
                MH_Unconstrained_TH_rate, \
                MH_Unconstrained_TH_SI_rate
#end method

def process_BUSTEDS(filename_MH, filename):
    global BUSTEDS_OUTPUT_CSV
    p_value_BUSTEDS, BASE_Unconstrained_cAIC, BASE_Unconstrained_log_L = read_json_BUSTEDS(filename)
    
    p_value_BUSTEDS_MH, MH_MG94_cAIC, MH_MG94_log_L, MH_MG94_dNdS, MH_MG94_DH_rate, MH_MG94_TH_rate, MH_MG94_TH_SI_rate, MH_Unconstrained_cAIC, MH_Unconstrained_log_L, MH_Unconstrained_DH_rate, \
                MH_Unconstrained_TH_rate, \
                MH_Unconstrained_TH_SI_rate  = read_json_BUSTEDS_MH(filename_MH)
    
    #Calculate aBSREL-MH minus aBSREL
    #delta_cAIC = float(cAIC_aBSREL_MH) - float(cAIC_aBSREL)
    #print("\t### RESULT", delta_cAIC)
    delta_p_value = float(p_value_BUSTEDS_MH) - float(p_value_BUSTEDS)
    #Check for errors
    if p_value_BUSTEDS == 9999990 or p_value_BUSTEDS_MH == 9999991: return 1
    #Output to csv
    with open(BUSTEDS_OUTPUT_CSV, 'a', newline='') as csvfile:
        spamwriter = csv.writer(csvfile, delimiter=',',
                                quotechar='|', quoting=csv.QUOTE_MINIMAL)
        spamwriter.writerow([filename_MH.split("/")[-1].replace(".BUSTEDS.json", ""), str(p_value_BUSTEDS_MH), str(p_value_BUSTEDS), str(delta_p_value),
                             BASE_Unconstrained_cAIC, BASE_Unconstrained_log_L, \
                             MH_MG94_cAIC, MH_MG94_log_L, \
                                 MH_MG94_dNdS, MH_MG94_DH_rate, MH_MG94_TH_rate, MH_MG94_TH_SI_rate, \
                                 MH_Unconstrained_cAIC, MH_Unconstrained_log_L, \
                                     MH_Unconstrained_DH_rate, \
                                     MH_Unconstrained_TH_rate, \
                                     MH_Unconstrained_TH_SI_rate
                             ])
    csvfile.close()
    #end with
#end method

# %%
# =============================================================================
# Main subroutine
# =============================================================================
print("# Init ")
print("# Program is in:", os.getcwd())
print("# Saving output to:", BUSTEDS_OUTPUT_CSV)

#Empty out the output CSV
with open(BUSTEDS_OUTPUT_CSV, 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)
    spamwriter.writerow(["Filename", "pvalue_BUSTEDSMH", "pvalue_BUSTEDS", "delta p-values", \
                         "BASE_Unconstrained_cAIC", "BASE_Unconstrained_log_L",
                         "MH_MG94x(2+3)_cAIC", "MH_MG94x(2+3)_log_L", "MH_MG94x(2+3)_dNdS", "MH_MG94x(2+3)_DH_rate", "MH_MG94x(2+3)_TH_rate", "MH_MG94x(2+3)_TH_SI_rate", \
                         "MH_Unconstrained_cAIC", "MH_Unconstrained_log_L", \
                         "MH_Unconstrained_DH_rate", "MH_Unconstrained_TH_rate", "MH_Unconstrained_TH_SI_rate"])
csvfile.close()
#end with
    
print("# Processing ", BUSTEDS_DIR)
print("# Processing ", BUSTEDS_MH_DIR)
BASE_tag = ""
MH_tag = ""

BUSTEDS_DIR_FILES = [os.path.join(BUSTEDS_DIR, file.name) for file in os.scandir(BUSTEDS_DIR) if file.name.endswith(".BUSTEDS.json")]
BUSTEDS_MH_DIR_FILES = [os.path.join(BUSTEDS_MH_DIR, file.name) for file in os.scandir(BUSTEDS_MH_DIR) if file.name.endswith(".BUSTEDS-MH.json")]
print("# Number of BUSTEDS results:", len(BUSTEDS_DIR_FILES))
print("# Number of BUSTEDS-MH results:", len(BUSTEDS_MH_DIR_FILES))

# Loop over files in aBSREL-MH_DIR
matches_count = 0
for n, file in enumerate(BUSTEDS_MH_DIR_FILES):
    if os.stat(file).st_size == 0: 
        print("# Encountered empty file:", file)
        continue
    #end if
    
    #print("# Searching for match for:", file.split("/")[-1])
    print("#", n+1, "Searching for match for:", file)
    
    NEXUS_FILENAME = file.split("/")[-1].replace(".BUSTEDS-MH.json", "") 
    
    BUSTEDS_VERSION = os.path.join(BUSTEDS_DIR, NEXUS_FILENAME) + ".BUSTEDS.json"
    
    if os.stat(file).st_size > 0: 
        print("# Checking for BUSTEDS output for:", BUSTEDS_VERSION)
    else:
        continue
    #end if
    
    # Does it match with a file in aBSREL_DIR?, if soo..
    if BUSTEDS_VERSION in BUSTEDS_DIR_FILES:
        # process
        matches_count += 1
        process_BUSTEDS(file, BUSTEDS_VERSION)
    else:
        # dont process, but record this.
        pass
    # end if
    print()
#end for

print("# Number of matches:", matches_count)
# Out:
# # Init
# # Program is in: /Users/user/Documents/BS-MH/scripts
# # Saving output to: PROCESSED_PairedAnalysis_13datasets_BUSTEDS-MH_vs_BUSTEDS.csv
# # Processing  /Users/user/Documents/PRELIM_2020/14-datasets/BUSTEDS
# # Processing  /Users/user/Documents/PRELIM_2020/14-datasets/BUSTEDS-MH
# # Number of BUSTEDS results: 13
# # Number of BUSTEDS-MH results: 13
# # 1 Searching for match for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/InfluenzaA.nex.BUSTEDS-MH.json
# # Checking for BUSTEDS output for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/InfluenzaA.nex.BUSTEDS.json
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/InfluenzaA.nex.BUSTEDS.json
# 	Baseline model (BUSTEDS) p-value = 0.1047127986361128
# 	Baseline model (BUSTEDS) Unconstrained cAIC = 23242.49538542873
# 	Baseline model (BUSTEDS) Unconstrained logL = -11051.42889583376
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/InfluenzaA.nex.BUSTEDS-MH.json
# 	Novel model (BUSTEDS-MH) p-value = 0.5
# 	Novel model (BUSTEDS-MH) cAIC = 23230.10669984552
# 	Novel model (BUSTEDS-MH) logL = -11042.20459718753
#
# # 2 Searching for match for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/COXI.nex.BUSTEDS-MH.json
# # Checking for BUSTEDS output for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/COXI.nex.BUSTEDS.json
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/COXI.nex.BUSTEDS.json
# 	Baseline model (BUSTEDS) p-value = 0.5
# 	Baseline model (BUSTEDS) Unconstrained cAIC = 24288.71170588409
# 	Baseline model (BUSTEDS) Unconstrained logL = -12080.97711914531
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/COXI.nex.BUSTEDS-MH.json
# 	Novel model (BUSTEDS-MH) p-value = 0.5
# 	Novel model (BUSTEDS-MH) cAIC = 24295.52533688448
# 	Novel model (BUSTEDS-MH) logL = -12081.34718408633
#
# # 3 Searching for match for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/flavNS5.nex.BUSTEDS-MH.json
# # Checking for BUSTEDS output for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/flavNS5.nex.BUSTEDS.json
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/flavNS5.nex.BUSTEDS.json
# 	Baseline model (BUSTEDS) p-value = 0.4822038677944333
# 	Baseline model (BUSTEDS) Unconstrained cAIC = 18530.58019870966
# 	Baseline model (BUSTEDS) Unconstrained logL = -9207.74795438927
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/flavNS5.nex.BUSTEDS-MH.json
# 	Novel model (BUSTEDS-MH) p-value = 0.5
# 	Novel model (BUSTEDS-MH) cAIC = 18488.62691221152
# 	Novel model (BUSTEDS-MH) logL = -9183.712963899032
#
# # 4 Searching for match for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/ENCenv.nex.BUSTEDS-MH.json
# # Checking for BUSTEDS output for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/ENCenv.nex.BUSTEDS.json
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/ENCenv.nex.BUSTEDS.json
# 	Baseline model (BUSTEDS) p-value = 0.5
# 	Baseline model (BUSTEDS) Unconstrained cAIC = 13699.07848237643
# 	Baseline model (BUSTEDS) Unconstrained logL = -6782.140710747347
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/ENCenv.nex.BUSTEDS-MH.json
# 	Novel model (BUSTEDS-MH) p-value = 0.5
# 	Novel model (BUSTEDS-MH) cAIC = 13705.10984981396
# 	Novel model (BUSTEDS-MH) logL = -6782.12006621418
#
# # 5 Searching for match for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/adh.nex.BUSTEDS-MH.json
# # Checking for BUSTEDS output for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/adh.nex.BUSTEDS.json
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/adh.nex.BUSTEDS.json
# 	Baseline model (BUSTEDS) p-value = 0.001639209329015068
# 	Baseline model (BUSTEDS) Unconstrained cAIC = 9353.863170589633
# 	Baseline model (BUSTEDS) Unconstrained logL = -4609.142530913105
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/adh.nex.BUSTEDS-MH.json
# 	Novel model (BUSTEDS-MH) p-value = 0.01947416117450618
# 	Novel model (BUSTEDS-MH) cAIC = 9359.172806510542
# 	Novel model (BUSTEDS-MH) logL = -4608.725200690724
#
# # 6 Searching for match for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/HIVvif.nex.BUSTEDS-MH.json
# # Checking for BUSTEDS output for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/HIVvif.nex.BUSTEDS.json
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/HIVvif.nex.BUSTEDS.json
# 	Baseline model (BUSTEDS) p-value = 0.02270882852036099
# 	Baseline model (BUSTEDS) Unconstrained cAIC = 6911.64906988795
# 	Baseline model (BUSTEDS) Unconstrained logL = -3377.730545872937
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/HIVvif.nex.BUSTEDS-MH.json
# 	Novel model (BUSTEDS-MH) p-value = 0.5
# 	Novel model (BUSTEDS-MH) cAIC = 6911.008312547014
# 	Novel model (BUSTEDS-MH) logL = -3374.323183064103
#
# # 7 Searching for match for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/camelid.nex.BUSTEDS-MH.json
# # Checking for BUSTEDS output for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/camelid.nex.BUSTEDS.json
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/camelid.nex.BUSTEDS.json
# 	Baseline model (BUSTEDS) p-value = 0
# 	Baseline model (BUSTEDS) Unconstrained cAIC = 33694.60454183659
# 	Baseline model (BUSTEDS) Unconstrained logL = -16454.85911755758
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/camelid.nex.BUSTEDS-MH.json
# 	Novel model (BUSTEDS-MH) p-value = 0.005553944348468176
# 	Novel model (BUSTEDS-MH) cAIC = 33668.36327010485
# 	Novel model (BUSTEDS-MH) logL = -16438.62104796631
#
# # 8 Searching for match for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/lysozyme.nex.BUSTEDS-MH.json
# # Checking for BUSTEDS output for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/lysozyme.nex.BUSTEDS.json
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/lysozyme.nex.BUSTEDS.json
# 	Baseline model (BUSTEDS) p-value = 0.5
# 	Baseline model (BUSTEDS) Unconstrained cAIC = 2145.577703032143
# 	Baseline model (BUSTEDS) Unconstrained logL = -1017.559037851475
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/lysozyme.nex.BUSTEDS-MH.json
# 	Novel model (BUSTEDS-MH) p-value = 0.5
# 	Novel model (BUSTEDS-MH) cAIC = 2151.862413074277
# 	Novel model (BUSTEDS-MH) logL = -1017.560559770969
#
# # 9 Searching for match for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/HIV_RT.nex.BUSTEDS-MH.json
# # Checking for BUSTEDS output for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/HIV_RT.nex.BUSTEDS.json
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/HIV_RT.nex.BUSTEDS.json
# 	Baseline model (BUSTEDS) p-value = 7.174705274337612e-11
# 	Baseline model (BUSTEDS) Unconstrained cAIC = 52048.51841358669
# 	Baseline model (BUSTEDS) Unconstrained logL = -25075.64342037431
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/HIV_RT.nex.BUSTEDS-MH.json
# 	Novel model (BUSTEDS-MH) p-value = 0.001197610561663842
# 	Novel model (BUSTEDS-MH) cAIC = 52050.84852161718
# 	Novel model (BUSTEDS-MH) logL = -25073.77259816893
#
# # 10 Searching for match for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/HepatitisD.nex.BUSTEDS-MH.json
# # Checking for BUSTEDS output for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/HepatitisD.nex.BUSTEDS.json
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/HepatitisD.nex.BUSTEDS.json
# 	Baseline model (BUSTEDS) p-value = 1.118887693607462e-08
# 	Baseline model (BUSTEDS) Unconstrained cAIC = 10424.22529578519
# 	Baseline model (BUSTEDS) Unconstrained logL = -5123.912647892595
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/HepatitisD.nex.BUSTEDS-MH.json
# 	Novel model (BUSTEDS-MH) p-value = 0.03227677257905226
# 	Novel model (BUSTEDS-MH) cAIC = 10418.26345775442
# 	Novel model (BUSTEDS-MH) logL = -5117.847425913435
#
# # 11 Searching for match for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/bglobin.nex.BUSTEDS-MH.json
# # Checking for BUSTEDS output for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/bglobin.nex.BUSTEDS.json
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/bglobin.nex.BUSTEDS.json
# 	Baseline model (BUSTEDS) p-value = 1.182876129640631e-05
# 	Baseline model (BUSTEDS) Unconstrained cAIC = 7415.590435899347
# 	Baseline model (BUSTEDS) Unconstrained logL = -3651.507592531613
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/bglobin.nex.BUSTEDS-MH.json
# 	Novel model (BUSTEDS-MH) p-value = 0.002194763027228763
# 	Novel model (BUSTEDS-MH) cAIC = 7384.667181616638
# 	Novel model (BUSTEDS-MH) logL = -3632.901192315226
#
# # 12 Searching for match for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/yokoyama.rh1.cds.mod.1-990.nex.BUSTEDS-MH.json
# # Checking for BUSTEDS output for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/yokoyama.rh1.cds.mod.1-990.nex.BUSTEDS.json
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/yokoyama.rh1.cds.mod.1-990.nex.BUSTEDS.json
# 	Baseline model (BUSTEDS) p-value = 1.0997758402298e-06
# 	Baseline model (BUSTEDS) Unconstrained cAIC = 25924.30518545799
# 	Baseline model (BUSTEDS) Unconstrained logL = -12867.43503547708
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/yokoyama.rh1.cds.mod.1-990.nex.BUSTEDS-MH.json
# 	Novel model (BUSTEDS-MH) p-value = 0.08975829996611812
# 	Novel model (BUSTEDS-MH) cAIC = 25895.9487969114
# 	Novel model (BUSTEDS-MH) logL = -12850.21037337934
#
# # 13 Searching for match for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/lysin.nex.BUSTEDS-MH.json
# # Checking for BUSTEDS output for: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/lysin.nex.BUSTEDS.json
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS/lysin.nex.BUSTEDS.json
# 	Baseline model (BUSTEDS) p-value = 0
# 	Baseline model (BUSTEDS) Unconstrained cAIC = 8765.45910068457
# 	Baseline model (BUSTEDS) Unconstrained logL = -4310.170062849911
# # Reading: /Users/user/Documents/BS-MH/analysis/13-datasets/BUSTEDS-MH/lysin.nex.BUSTEDS-MH.json
# 	Novel model (BUSTEDS-MH) p-value = 1.16458382942719e-06
# 	Novel model (BUSTEDS-MH) cAIC = 8767.431031855995
# 	Novel model (BUSTEDS-MH) logL = -4308.020859439448
#
# # Number of matches: 13

# %%
# =============================================================================
# End of file
# =============================================================================
